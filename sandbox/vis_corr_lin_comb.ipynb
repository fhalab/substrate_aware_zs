# %%
# %cd ~/REVIVAL2
# Out:
# /disk2/fli/REVIVAL2

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
lib_order = [
    "PfTrpB-7iodo",
    "PfTrpB-7methyl",
    "PfTrpB-7bromo",
    "PfTrpB-5iodo",
    "PfTrpB-5bromo",
    "PfTrpB-5chloro",
    "PfTrpB-4bromo",
    "PfTrpB-6chloro",
    "PfTrpB-5cyano",
    "PfTrpB-4cyano",
    "PfTrpB-56chloro",
    "Rma-CB",
    "Rma-CSi",
    "ParLQ-a",
    "ParLQ-b",
    "ParLQ-c",
    "ParLQ-d",
    "ParLQ-e",
    "ParLQ-f",
    "ParLQ-g",
    "ParLQ-h",
    "ParLQ-i",
]

# %%
pd.read_csv('/disk2/fli/REVIVAL2/zs/lincomb/lin_rho_pairwise_df.csv', index_col=0).mean(axis=1).sort_values(ascending=False)
# Out:
# ParLQ-f            0.392539
# ParLQ-g            0.365374
# PfTrpB-5iodo       0.348686
# PfTrpB-5bromo      0.318318
# PfTrpB-7iodo       0.313246
# Rma-CSi            0.312974
# Rma-CB             0.303680
# PfTrpB-7methyl     0.294529
# PfTrpB-6chloro     0.292325
# PfTrpB-7bromo      0.288605
# PfTrpB-4cyano      0.286042
# PfTrpB-5chloro     0.280862
# ParLQ-d            0.261190
# ParLQ-e            0.251081
# ParLQ-h            0.246482
# PfTrpB-5cyano      0.236557
# PfTrpB-56chloro    0.236416
# PfTrpB-4bromo      0.215281
# ParLQ              0.208404
# ParLQ-i            0.165771
# ParLQ-b            0.143085
# ParLQ-c            0.136674
# dtype: float64

# %%
corr_df = pd.read_csv('/disk2/fli/REVIVAL2/zs/lincomb/lin_rho_pairwise_df.csv', index_col=0).reset_index(drop=True).rename(columns={"ParLQ": "ParLQ-a"})
corr_df["Library"] = corr_df.columns
corr_df.set_index("Library", inplace=True)
corr_df = corr_df.reindex(lib_order)[lib_order]
corr_df
# Out:
#                  PfTrpB-7iodo  PfTrpB-7methyl  PfTrpB-7bromo  PfTrpB-5iodo  \
# Library
# PfTrpB-7iodo         0.692202        0.619127       0.645952      0.455881
# PfTrpB-7methyl       0.698320        0.703278       0.700195      0.526830
# PfTrpB-7bromo        0.664058        0.617048       0.766462      0.439927
# PfTrpB-5iodo         0.572966        0.550123       0.584571      0.515390
# PfTrpB-5bromo        0.649709        0.624217       0.626217      0.504303
# PfTrpB-5chloro       0.602497        0.618235       0.570142      0.531421
# PfTrpB-4bromo        0.525832        0.497160       0.405085      0.276309
# PfTrpB-6chloro       0.661495        0.669681       0.614345      0.521927
# PfTrpB-5cyano        0.502269        0.502322       0.349009      0.210659
# PfTrpB-4cyano        0.573252        0.517339       0.576249      0.478263
# PfTrpB-56chloro      0.521823        0.549632       0.530404      0.484422
# ...

# %%
# Set the figure size
plt.figure(figsize=(10, 8))
# Create a heatmap
sns.heatmap(
    corr_df,
    # .set_index("Library")
    # .reindex(["PfTrpB-avg", "Rma-CB", "Rma-CSi", "ParLQ-avg"]),
    cmap="vlag",
    annot=True,
    fmt=".1f",
    linewidths=0.5,
    cbar_kws={"label": "Spearman's ρ\n(activity)", "ticks": [0, 0.5], "shrink": 0.5},
    vmin=-0.25,
    vmax=0.7
)
# Add title and labels
plt.xlabel("Testing")
plt.ylabel("Training")
# save the output
plt.savefig("/disk2/fli/REVIVAL2/figs/zs_lin_rho_pairwise_df_all.svg", dpi=300, bbox_inches="tight")

# %%
corr_df["ParLQ-avg"] = corr_df[[c for c in lib_order if "ParLQ" in c]].mean(axis=1)
corr_df["PfTrpB-avg"] = corr_df[[c for c in lib_order if "PfTrpB" in c]].mean(axis=1)

groups = {"ParLQ-avg": [c for c in lib_order if "ParLQ" in c], "PfTrpB-avg": [c for c in lib_order if "PfTrpB" in c]}

for new_row, rows in groups.items():
    corr_df.loc[new_row] = corr_df.loc[rows].mean()

# %%
corr_df.loc[["PfTrpB-avg", "Rma-CB", "Rma-CSi", "ParLQ-avg"]]
# Out:
#             PfTrpB-7iodo  PfTrpB-7methyl  PfTrpB-7bromo  PfTrpB-5iodo  \
# Library
# PfTrpB-avg      0.605857        0.588015       0.578966      0.449576
# Rma-CB          0.542943        0.543935       0.530786      0.255779
# Rma-CSi         0.479512        0.466874       0.468947      0.238308
# ParLQ-avg       0.176692        0.099686       0.142968      0.095779
#
#             PfTrpB-5bromo  PfTrpB-5chloro  PfTrpB-4bromo  PfTrpB-6chloro  \
# Library
# PfTrpB-avg       0.513335        0.576004       0.541123        0.615523
# Rma-CB           0.320359        0.357070       0.391988        0.511443
# Rma-CSi          0.289733        0.362386       0.326368        0.434535
# ParLQ-avg        0.090481        0.063524       0.145049        0.097771
#
#             PfTrpB-5cyano  PfTrpB-4cyano  ...   ParLQ-b   ParLQ-c   ParLQ-d  \
# Library                                   ...
# PfTrpB-avg       0.480152       0.388052  ... -0.104451 -0.028970 -0.061463
# ...

# %%
corr_df.loc[["PfTrpB-avg", "Rma-CB", "Rma-CSi", "ParLQ-avg"]][["PfTrpB-avg", "Rma-CB", "Rma-CSi", "ParLQ-avg"]]
# Out:
#             PfTrpB-avg    Rma-CB   Rma-CSi  ParLQ-avg
# Library
# PfTrpB-avg    0.525251  0.247720  0.157539   0.004302
# Rma-CB        0.391247  0.567446  0.364702   0.160565
# Rma-CSi       0.354819  0.463450  0.482589   0.226265
# ParLQ-avg     0.108764  0.133173  0.082942   0.432599

# %%
# Set the figure size
plt.figure(figsize=(2.1, 1.6))
# Create a heatmap
sns.heatmap(
    corr_df.loc[["PfTrpB-avg", "Rma-CB", "Rma-CSi", "ParLQ-avg"]][["PfTrpB-avg", "Rma-CB", "Rma-CSi", "ParLQ-avg"]],
    # .reindex(LIB_ORDER),
    cmap="vlag",
    annot=True,
    fmt=".1f",
    linewidths=0.5,
    cbar_kws={"label": "Spearman's ρ\n(activity)", "ticks": [0, 0.5]},
    vmin=-0.25,
    vmax=0.55
)
# Show the plot
# plt.title("ZS Summary: Spearman correlation")
plt.xlabel("Testing")
plt.ylabel("Training")
plt.savefig("figs/zs_lin_rho_pairwise_df.svg", format="svg", dpi=300, bbox_inches="tight")

# %%
from scipy.stats import spearmanr

# %%
FINAL_COL_ORDER = [
    "Library",
    "Hamming distance",
    "EVmutation",
    "ESM2",
    "ESM-IF",
    "CoVES",
    r"ΔΔ$G_f$",  # "ΔΔG",
    "Vina",
    "GALigandDock",
    "AF3",
    "Chai-1",
    "LigandMPNN",
    "FlowSite",
    "Bond distance",
    "Hydrogen bonds",
    "Hydrophobicity",
    "Active-site volume",
]

# %%
all_weights = np.zeros((len(FINAL_COL_ORDER) - 1, 1))
trp_weights = np.zeros((len(FINAL_COL_ORDER) - 1, 1))
rma_cb_weights = np.zeros((len(FINAL_COL_ORDER) - 1, 1))
rma_csi_weights = np.zeros((len(FINAL_COL_ORDER) - 1, 1))
parlq_weights = np.zeros((len(FINAL_COL_ORDER) - 1, 1))

numb_all = 0
numb_trp = 0
numb_rma_cb = 0
numb_rma_csi = 0
numb_parlq = 0

for lib in lib_order:
    if lib == "ParLQ-a":
        lib = "ParLQ"
    intercept, weights = np.load("/disk2/fli/REVIVAL2/zs/lincomb/lin_params.npz", allow_pickle=True)[f"train_fold_{lib}_test_fold_{lib}"]
    all_weights += weights.reshape(-1, 1)
    numb_all += 1
    if "TrpB" in lib:
        trp_weights += weights.reshape(-1, 1)
        numb_trp += 1
    if "Rma-CB" in lib:
        rma_cb_weights += weights.reshape(-1, 1)
        numb_rma_cb += 1
    if "Rma-CSi" in lib:
        rma_csi_weights += weights.reshape(-1, 1)
        numb_rma_csi += 1
    if "ParLQ" in lib:
        parlq_weights += weights.reshape(-1, 1)
        numb_parlq += 1

    # plot barplot of the weights
    plt.figure(figsize=(10, 4))
    
    plt.bar(range(len(weights)), weights)
    # add title
    plt.title(lib)
    plt.xticks(range(len(weights)), FINAL_COL_ORDER[1:], rotation=90)
    plt.show()

all_weights /= numb_all
trp_weights /= numb_trp
rma_cb_weights /= numb_rma_cb
rma_csi_weights /= numb_rma_csi
parlq_weights /= numb_parlq

# %%
# Create the scatter plot
plt.figure(figsize=(8,4))
plt.yscale('symlog')
# add a thin gray line at y=0 and make it to the back
plt.axhline(0, color='gray', linewidth=1, ls="dotted", zorder=-1)

x_values = np.arange(1, 17)
plt.scatter(x_values, trp_weights, color='#00a1df', label='PfTrpB-avg', marker='o', s=120, alpha=0.8, linewidths=1.2)
plt.scatter(x_values, rma_cb_weights, color='#9bbb59', label='Rma-CB', marker='s', s=120, alpha=0.4, linewidths=1.2)
plt.scatter(x_values, rma_csi_weights, color='#9bbb59', label='Rma-CSi', marker='^', s=120, alpha=0.6, linewidths=1.2)
plt.scatter(x_values, parlq_weights, color='#9bbb59', label='ParLQ-avg', marker='o', s=120, alpha=0.8, linewidths=1.2)
plt.scatter(x_values, all_weights, color="gray", label='All', marker='x', s=100, alpha=0.8, linewidths=1.2) # yellow

plt.xticks(x_values, FINAL_COL_ORDER[1:], rotation=90)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
# make y semilog

plt.ylabel('Weights')
# remove top and right spines
sns.despine()
# save
plt.savefig('figs/zs_lin_weights.svg', format='svg', dpi=300, bbox_inches='tight')
plt.show()
